# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/content/drive/MyDrive/Simple-Python-Chatbot-master/Simple-Python-Chatbot-master/intents 1 (2).json').read()
intents = json.loads(data_file)
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('/content/drive/MyDrive/Simple-Python-Chatbot-master/Simple-Python-Chatbot-master/words3.pkl','wb'))
pickle.dump(classes,open('/content/drive/MyDrive/Simple-Python-Chatbot-master/Simple-Python-Chatbot-master/classes3.pkl','wb'))
# Out:
# 331 documents
# 35 classes ['Affiliation', 'Bold', 'Bullet list', 'Decrease Indent', 'Hide track changes', 'Increase Indent', 'Insert special character', 'Merge with next', 'Merge with previous', 'Move Down', 'Move up', 'Number list', 'Place float', 'Place inline', 'Redo', 'Show track changes', 'Spell check', 'Undo', 'Upload Offline PDF', 'article type', 'background color', 'change case', 'copy', 'corresponding author', 'cut', 'goodbye', 'greeting', 'italic', 'options', 'section head', 'subscript', 'superscript', 'text color', 'thanks', 'underline']
# 354 unique lemmatized words ["'m", "'s", "'ve", ',', 'a', 'academic', 'accidentally', 'add', 'adding', 'adjust', 'adjusting', 'affiliation', 'after', 'already', 'altering', 'am', 'amount', 'an', 'and', 'another', 'any', 'anyone', 'appear', 'appearance', 'appears', 'application', 'applied', 'apply', 'applying', 'are', 'article', 'at', 'author', 'available', 'awesome', 'back', 'background', 'be', 'been', 'before', 'being', 'best', 'between', 'bold', 'bullet', 'bulleted', 'by', 'bye', 'can', 'capitalization', 'capitalized', 'case', 'change', 'changing', 'character', 'chatting', 'check', 'collaborator', 'color', 'combine', 'comment', 'consistent', 'content', 'convert', 'converting', 'copied', 'copy', 'copying', 'correct', 'correctly', 'corresponding', 'could', 'create', 'creating', 'custom', 'customize', 'cut', 'cutting', 'day', 'decrease', 'decreasing', 'delete', 'demonstrate', 'designate', 'designating', 'dictionary', 'did', 'difference', 'different', 'do', 'document', 'doe', 'down', 'duplicate', 'each', 'edit', 'effect', 'ensure', 'entire', 'error', 'existing', 'explain', 'far', 'feature', 'field', 'file', 'first', 'float', 'floating', 'follow', 'font', 'for', 'format', 'formatted', 'formatting', 'free', 'from', 'function', 'further', 'give', 'giving', 'glyph', 'good', 'goodbye', 'gradient', 'guide', 'ha', 'hanging', 'happens', 'have', 'head', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hide', 'hiding', 'higher', 'hola', 'how', 'i', 'identity', 'if', 'important', 'in', 'include', 'including', 'increase', 'increasing', 'indent', 'indentation', 'indented', 'indicate', 'information', 'inline', 'insert', 'inserting', 'insertion', 'intend', 'into', 'is', 'it', 'italic', 'italicized', 'key', 'keyboard', 'later', 'left', 'letter', 'like', 'limitation', 'line', 'list', 'location', 'lower', 'lowercase', 'made', 'make', 'making', 'manner', 'manuscript', 'many', 'margin', 'mark', 'match', 'me', 'meet', 'menu', 'merge', 'merged', 'merging', 'method', 'mind', 'misspelled', 'modify', 'mouse', 'move', 'movement', 'moving', 'multiple', 'my', "n't", 'navigate', 'need', 'nested', 'new', 'next', 'nice', 'not', 'number', 'numbered', 'object', 'of', 'off', 'offered', 'offline', 'on', 'once', 'one', 'only', 'operation', 'option', 'or', 'other', 'overlap', 'own', 'page', 'paper', 'paragraph', 'paste', 'patterned', 'pdf', 'placement', 'placing', 'platform', 'point', 'portion', 'possible', 'practice', 'previous', 'previously', 'procedure', 'process', 'provide', 'publication', 'purpose', 'quickly', 'recent', 'redid', 'redo', 'redoing', 'regular', 'remove', 'requirement', 'research', 'restore', 'restriction', 'reverse', 'reversing', 'reverted', 'right', 'role', 'running', 'scholarly', 'search', 'section', 'see', 'selected', 'selection', 'set', 'setting', 'shortcut', 'should', 'show', 'showing', 'size', 'so', 'software', 'some', 'spacing', 'special', 'specific', 'specify', 'spell', 'spelling', 'step', 'stored', 'structured', 'style', 'submission', 'submitting', 'subscript', 'subscripted', 'such', 'superscript', 'superscripted', 'support', 'sure', 'surrounding', 'switch', 'symbol', 'text', 'thank', 'thanks', 'that', 'the', 'them', 'there', 'through', 'till', 'time', 'title', 'to', 'toggle', 'tool', 'track', 'tracked', 'transparent', 'turning', 'tutorial', 'two', 'type', 'underline', 'underlined', 'undid', 'undo', 'undoing', 'up', 'update', 'upload', 'uploading', 'uppercase', 'use', 'user', 'using', 'versa', 'vice', 'visible', 'wa', 'walk', 'want', 'way', 'website', 'what', 'when', 'where', 'which', 'who', 'why', 'with', 'word', 'you']
